# %%
from keras.models import Sequential
from keras.layers import Conv2D, ZeroPadding2D, Activation, Input, concatenate
from keras.models import Model
from keras.layers.normalization import BatchNormalization
from keras.layers.pooling import MaxPooling2D, AveragePooling2D
from keras.layers.merge import Concatenate
from keras.layers.core import Lambda, Flatten, Dense
from keras.initializers import glorot_uniform
from keras.engine.topology import Layer
from pathlib import Path
from keras import backend as K
from collections import defaultdict
from keras.models import load_model

K.set_image_data_format('channels_first')

import cv2
import os
import numpy as np
from PIL import Image
import tensorflow as tf
import time
from fr_utils import *

np.set_printoptions(threshold=np.nan)

# %%
def triplet_loss(y_true, y_pred, alpha = 0.2):

    anchor, positive, negative = y_pred[0], y_pred[1], y_pred[2]
    
    pos_dist = tf.reduce_sum(tf.square(tf.subtract(anchor, positive)))
    neg_dist = tf.reduce_sum(tf.square(tf.subtract(anchor, negative)))
    basic_loss = tf.add(tf.subtract(pos_dist, neg_dist), alpha)
    loss = tf.maximum(tf.reduce_mean(basic_loss), 0.0)
    
    return loss

# %%
Rmodel = load_model('my_model.h5', custom_objects={'triplet_loss': triplet_loss})

print("Total Params:", Rmodel.count_params())
# Out:
# Total Params: 3743280

# %%
def getAllFiles(pathDir2):
    pathDir = Path(pathDir2)
    files = [p for p in pathDir.iterdir() if p.is_file ()]
    return files;

# %%
#using pil to load image

def PIL2array(img):
    return np.array(img.getdata(), np.uint8).reshape(img.size[1], img.size[0], 3)

min_side = 600
np_imgs = []
all_imgs = getAllFiles('images/fulltest/')
for cur_img_path in all_imgs:
    img = Image.open(cur_img_path)
    img = img.convert('RGB')
    width, height = img.size
    if height < width:
        width = int(1.0 * width * min_side / height)
        height = min_side
    else:
        height = int(1.0 * height * min_side / width)
        width = min_side
    size = width + 1, height + 1
    img = img.resize(size)
    tmp = PIL2array(img)
    np_imgs.append(tmp)

# %%
#using cv2 to load image that 8 times faster than pil

min_side = 600
np_imgs = []
all_imgs = getAllFiles('images/fulltest/')

for cur_img_path in all_imgs:
    tmp = cv2.imread(str(cur_img_path), 1)
    height = tmp.shape[0]
    width = tmp.shape[1]
    if height < width:
        width = int(1.0 * width * min_side / height)
        height = min_side
    else:
        height = int(1.0 * height * min_side / width)
        width = min_side

    tmp = cv2.resize(tmp,(width + 1, height + 1)) 
    np_imgs.append(tmp)

# %%
dim = 200
stride = 100

mat = []
encodings = []

start_time = time.time()

for row in range(0, int(3 * min_side / 2), stride):
    for col in range(0, int(3 * min_side / 2), stride):
        mat.append([row, col])


for cur_img in np_imgs:
    tmp = []
    for r in mat:
        if cur_img.shape[0] - dim > r[0] and cur_img.shape[1] - dim > r[1]:
            tmp.append(img_to_encoding_range(dim, r[0], r[1], cur_img, Rmodel))
    tmp.append(img_to_encoding(cur_img, Rmodel))
    tmp.append(img_to_encoding_bot(cur_img, Rmodel))
    tmp.append(img_to_encoding_top(cur_img, Rmodel))
    encodings.append(tmp)

print(time.time() - start_time)
# Out:
# 109.40640044212341

# %%
def union_find(tree_size):
    for i in range(0, tree_size):
        par.append(i)

def get_par(cur_node):
    if cur_node == par[cur_node]:
        return cur_node
    else:
        par[cur_node] = get_par(par[cur_node])
        return par[cur_node]

def merge(a, b):
    a = get_par(a)
    b = get_par(b)
    par[a] = b

# %%
MIN_EPS = 0.94
MAX_EPS = 1.04

def size_compare(a, b):
    ret = (1.0 * a[0] * b[1]) / (1.0 * a[1] * b[0]) 
    if ret > MIN_EPS and ret < MAX_EPS:
        return True
    else:
        return False

# %%
par = []
union_find(len(encodings))
for i in range(0, len(encodings)):
    for j in range(i + 1, len(encodings)):
        if size_compare(np_imgs[i].shape, np_imgs[j].shape) == False:
            continue
        cnt = 0
        size = min(len(encodings[i]), len(encodings[j]))
        for k in range(0, size):
            dist = np.linalg.norm(encodings[i][k]-encodings[j][k])
            if dist < 0.42:
                cnt += 1
        if cnt > size / 4 + 1:
            merge(i, j)
        
d = defaultdict(list)
for i in range(0, len(encodings)):
    cur_par = get_par(i)
    d[cur_par].append(all_imgs[i])

failed = 0

for cur_par in d:
    print("----------------------------")
    print("Parent : ", cur_par)
    print("----------------------------")
    print(d[cur_par])
    if len(d[cur_par]) == 1:
        failed += 1
    #    print(d[cur_par])
print(len(d))
print(failed)
# Out:
# ----------------------------
# Parent :  99
# ----------------------------
# [PosixPath('images/fulltest/6597_4.jpg'), PosixPath('images/fulltest/6622_5.jpg'), PosixPath('images/fulltest/6622_6.jpg'), PosixPath('images/fulltest/6597_2.jpg'), PosixPath('images/fulltest/6597_5.jpg'), PosixPath('images/fulltest/6622_1.jpg'), PosixPath('images/fulltest/6622_4.jpg'), PosixPath('images/fulltest/6622_2.jpg'), PosixPath('images/fulltest/6597_3.jpg'), PosixPath('images/fulltest/6597_6.jpg'), PosixPath('images/fulltest/6597_1.jpg'), PosixPath('images/fulltest/6622_3.jpg')]
# ----------------------------
# Parent :  373
# ----------------------------
# [PosixPath('images/fulltest/7128_2.jpg'), PosixPath('images/fulltest/7128_6.jpg'), PosixPath('images/fulltest/7128_3.jpg'), PosixPath('images/fulltest/7128_1.jpg'), PosixPath('images/fulltest/7128_4.jpg'), PosixPath('images/fulltest/7128_5.jpg')]
# ----------------------------
# Parent :  278
# ----------------------------
# [PosixPath('images/fulltest/3577_6.jpg'), PosixPath('images/fulltest/3577_5.jpg'), PosixPath('images/fulltest/3577_4.jpg'), PosixPath('images/fulltest/3577_3.jpg'), PosixPath('images/fulltest/3577_2.jpg'), PosixPath('images/fulltest/3577_1.jpg')]
# ----------------------------
# Parent :  322
# ----------------------------
# [PosixPath('images/fulltest/3135_6.jpg'), PosixPath('images/fulltest/3135_4.jpg'), PosixPath('images/fulltest/3133_3.jpg'), PosixPath('images/fulltest/3133_6.jpg'), PosixPath('images/fulltest/3133_4.jpg'), PosixPath('images/fulltest/3135_1.jpg'), PosixPath('images/fulltest/3134_6.jpg'), PosixPath('images/fulltest/3134_1.jpg'), PosixPath('images/fulltest/3133_1.jpg'), PosixPath('images/fulltest/3135_2.jpg'), PosixPath('images/fulltest/3133_5.jpg'), PosixPath('images/fulltest/3133_2.jpg'), PosixPath('images/fulltest/3135_5.jpg'), PosixPath('images/fulltest/3134_5.jpg'), PosixPath('images/fulltest/3134_3.jpg'), PosixPath('images/fulltest/3134_4.jpg'), PosixPath('images/fulltest/3134_2.jpg'), PosixPath('images/fulltest/3135_3.jpg')]
# ----------------------------
# Parent :  255
# ----------------------------
# [PosixPath('images/fulltest/2629_2.jpg'), PosixPath('images/fulltest/2629_5.jpg'), PosixPath('images/fulltest/2629_1.jpg'), PosixPath('images/fulltest/2629_4.jpg'), PosixPath('images/fulltest/2629_3.jpg'), PosixPath('images/fulltest/2629_6.jpg')]
# ----------------------------
# Parent :  369
# ----------------------------
# [PosixPath('images/fulltest/2621_6.jpg'), PosixPath('images/fulltest/2621_2.jpg'), PosixPath('images/fulltest/2621_1.jpg'), PosixPath('images/fulltest/2621_3.jpg'), PosixPath('images/fulltest/2621_5.jpg'), PosixPath('images/fulltest/2621_4.jpg')]
# ----------------------------
# Parent :  300
# ----------------------------
# [PosixPath('images/fulltest/9952_1.jpg'), PosixPath('images/fulltest/9952_2.jpg'), PosixPath('images/fulltest/9952_5.jpg'), PosixPath('images/fulltest/529_3.jpg'), PosixPath('images/fulltest/529_1.jpg'), PosixPath('images/fulltest/529_6.jpg'), PosixPath('images/fulltest/529_4.jpg'), PosixPath('images/fulltest/529_5.jpg'), PosixPath('images/fulltest/529_2.jpg'), PosixPath('images/fulltest/9952_6.jpg'), PosixPath('images/fulltest/9952_4.jpg'), PosixPath('images/fulltest/9952_3.jpg')]
# ----------------------------
# Parent :  339
# ----------------------------
# [PosixPath('images/fulltest/7134_3.jpg'), PosixPath('images/fulltest/7134_1.jpg'), PosixPath('images/fulltest/7134_5.jpg'), PosixPath('images/fulltest/7134_6.jpg'), PosixPath('images/fulltest/7134_4.jpg'), PosixPath('images/fulltest/7134_2.jpg')]
# ----------------------------
# Parent :  344
# ----------------------------
# [PosixPath('images/fulltest/6625_6.jpg'), PosixPath('images/fulltest/6625_1.jpg'), PosixPath('images/fulltest/6625_4.jpg'), PosixPath('images/fulltest/6625_5.jpg'), PosixPath('images/fulltest/6625_2.jpg')]
# ----------------------------
# Parent :  301
# ----------------------------
# [PosixPath('images/fulltest/6621_6.jpg'), PosixPath('images/fulltest/6621_4.jpg'), PosixPath('images/fulltest/6621_5.jpg'), PosixPath('images/fulltest/6621_3.jpg'), PosixPath('images/fulltest/6621_2.jpg'), PosixPath('images/fulltest/6621_1.jpg')]
# ----------------------------
# Parent :  299
# ----------------------------
# [PosixPath('images/fulltest/11287_3.jpg'), PosixPath('images/fulltest/11287_2.jpg'), PosixPath('images/fulltest/11287_4.jpg'), PosixPath('images/fulltest/11287_6.jpg'), PosixPath('images/fulltest/11287_1.jpg'), PosixPath('images/fulltest/11287_5.jpg')]
# ----------------------------
# Parent :  125
# ----------------------------
# [PosixPath('images/fulltest/4033_4.jpg'), PosixPath('images/fulltest/4033_2.jpg')]
# ----------------------------
# Parent :  14
# ----------------------------
# [PosixPath('images/fulltest/4033_6.jpg')]
# ----------------------------
# Parent :  320
# ----------------------------
# [PosixPath('images/fulltest/4110_6.jpg'), PosixPath('images/fulltest/4110_4.jpg'), PosixPath('images/fulltest/4110_3.jpg'), PosixPath('images/fulltest/4110_2.jpg'), PosixPath('images/fulltest/4110_5.jpg'), PosixPath('images/fulltest/4110_1.jpg')]
# ----------------------------
# Parent :  376
# ----------------------------
# [PosixPath('images/fulltest/2622_2.jpg'), PosixPath('images/fulltest/2622_5.jpg'), PosixPath('images/fulltest/2622_1.jpg'), PosixPath('images/fulltest/2622_6.jpg'), PosixPath('images/fulltest/2622_4.jpg'), PosixPath('images/fulltest/2622_3.jpg')]
# ----------------------------
# Parent :  352
# ----------------------------
# [PosixPath('images/fulltest/9595_1.jpg'), PosixPath('images/fulltest/9595_6.jpg'), PosixPath('images/fulltest/9595_4.jpg'), PosixPath('images/fulltest/9595_2.jpg'), PosixPath('images/fulltest/9595_5.jpg'), PosixPath('images/fulltest/9595_3.jpg')]
# ----------------------------
# Parent :  382
# ----------------------------
# [PosixPath('images/fulltest/5068_5.jpg'), PosixPath('images/fulltest/5068_4.jpg'), PosixPath('images/fulltest/5068_6.jpg'), PosixPath('images/fulltest/5068_2.jpg'), PosixPath('images/fulltest/5068_3.jpg'), PosixPath('images/fulltest/5068_1.jpg')]
# ----------------------------
# Parent :  390
# ----------------------------
# [PosixPath('images/fulltest/7257_6.jpg'), PosixPath('images/fulltest/7257_1.jpg'), PosixPath('images/fulltest/2631_6.jpg'), PosixPath('images/fulltest/7257_2.jpg'), PosixPath('images/fulltest/10508_4.jpg'), PosixPath('images/fulltest/10508_5.jpg'), PosixPath('images/fulltest/2631_5.jpg'), PosixPath('images/fulltest/2631_1.jpg'), PosixPath('images/fulltest/10508_2.jpg'), PosixPath('images/fulltest/7257_5.jpg'), PosixPath('images/fulltest/2631_3.jpg'), PosixPath('images/fulltest/10508_3.jpg'), PosixPath('images/fulltest/7257_3.jpg'), PosixPath('images/fulltest/10508_6.jpg'), PosixPath('images/fulltest/2631_2.jpg'), PosixPath('images/fulltest/7257_4.jpg'), PosixPath('images/fulltest/2631_4.jpg'), PosixPath('images/fulltest/10508_1.jpg')]
# ----------------------------
# Parent :  242
# ----------------------------
# [PosixPath('images/fulltest/2628_3.jpg'), PosixPath('images/fulltest/2628_4.jpg'), PosixPath('images/fulltest/2628_5.jpg'), PosixPath('images/fulltest/2628_1.jpg'), PosixPath('images/fulltest/2628_6.jpg'), PosixPath('images/fulltest/2628_2.jpg')]
# ----------------------------
# Parent :  269
# ----------------------------
# [PosixPath('images/fulltest/10068_5.jpg'), PosixPath('images/fulltest/10068_6.jpg'), PosixPath('images/fulltest/10068_4.jpg'), PosixPath('images/fulltest/10068_2.jpg'), PosixPath('images/fulltest/10068_3.jpg')]
# ----------------------------
# Parent :  350
# ----------------------------
# [PosixPath('images/fulltest/9456_6.jpg'), PosixPath('images/fulltest/9456_1.jpg'), PosixPath('images/fulltest/9456_4.jpg'), PosixPath('images/fulltest/9456_2.jpg'), PosixPath('images/fulltest/9456_3.jpg'), PosixPath('images/fulltest/9456_5.jpg')]
# ----------------------------
# Parent :  258
# ----------------------------
# [PosixPath('images/fulltest/6623_2.jpg'), PosixPath('images/fulltest/6623_1.jpg'), PosixPath('images/fulltest/6623_3.jpg'), PosixPath('images/fulltest/6623_5.jpg'), PosixPath('images/fulltest/6623_6.jpg')]
# ----------------------------
# Parent :  274
# ----------------------------
# [PosixPath('images/fulltest/6030_2.jpg'), PosixPath('images/fulltest/6030_3.jpg'), PosixPath('images/fulltest/6030_6.jpg'), PosixPath('images/fulltest/6030_5.jpg'), PosixPath('images/fulltest/6030_1.jpg'), PosixPath('images/fulltest/6030_4.jpg')]
# ----------------------------
# Parent :  155
# ----------------------------
# [PosixPath('images/fulltest/10751_2.jpg'), PosixPath('images/fulltest/10773_2.jpg'), PosixPath('images/fulltest/10751_1.jpg'), PosixPath('images/fulltest/10751_6.jpg'), PosixPath('images/fulltest/10773_5.jpg'), PosixPath('images/fulltest/10751_4.jpg'), PosixPath('images/fulltest/10773_6.jpg'), PosixPath('images/fulltest/10773_1.jpg'), PosixPath('images/fulltest/10751_5.jpg'), PosixPath('images/fulltest/10773_3.jpg'), PosixPath('images/fulltest/10773_4.jpg'), PosixPath('images/fulltest/10751_3.jpg')]
# ----------------------------
# Parent :  398
# ----------------------------
# [PosixPath('images/fulltest/2626_4.jpg'), PosixPath('images/fulltest/2626_5.jpg'), PosixPath('images/fulltest/2626_2.jpg'), PosixPath('images/fulltest/2626_3.jpg'), PosixPath('images/fulltest/2626_1.jpg'), PosixPath('images/fulltest/2626_6.jpg')]
# ----------------------------
# Parent :  383
# ----------------------------
# [PosixPath('images/fulltest/2702_5.jpg'), PosixPath('images/fulltest/2702_2.jpg'), PosixPath('images/fulltest/2702_3.jpg'), PosixPath('images/fulltest/2702_6.jpg'), PosixPath('images/fulltest/2702_4.jpg'), PosixPath('images/fulltest/2702_1.jpg')]
# ----------------------------
# Parent :  374
# ----------------------------
# [PosixPath('images/fulltest/7650_4.jpg'), PosixPath('images/fulltest/7650_5.jpg'), PosixPath('images/fulltest/7650_6.jpg'), PosixPath('images/fulltest/7650_2.jpg'), PosixPath('images/fulltest/7650_3.jpg'), PosixPath('images/fulltest/7650_1.jpg')]
# ----------------------------
# Parent :  375
# ----------------------------
# [PosixPath('images/fulltest/8979_6.jpg'), PosixPath('images/fulltest/8979_3.jpg'), PosixPath('images/fulltest/8979_1.jpg'), PosixPath('images/fulltest/8979_5.jpg'), PosixPath('images/fulltest/8979_4.jpg'), PosixPath('images/fulltest/8979_2.jpg')]
# ----------------------------
# Parent :  291
# ----------------------------
# [PosixPath('images/fulltest/8222_5.jpg'), PosixPath('images/fulltest/8222_6.jpg'), PosixPath('images/fulltest/8222_2.jpg'), PosixPath('images/fulltest/8222_3.jpg'), PosixPath('images/fulltest/8222_4.jpg')]
# ----------------------------
# Parent :  327
# ----------------------------
# [PosixPath('images/fulltest/9380_5.jpg'), PosixPath('images/fulltest/9380_6.jpg'), PosixPath('images/fulltest/9380_4.jpg'), PosixPath('images/fulltest/9380_1.jpg'), PosixPath('images/fulltest/9380_3.jpg'), PosixPath('images/fulltest/9380_2.jpg')]
# ----------------------------
# Parent :  318
# ----------------------------
# [PosixPath('images/fulltest/7254_6.jpg'), PosixPath('images/fulltest/7254_4.jpg'), PosixPath('images/fulltest/7254_3.jpg'), PosixPath('images/fulltest/7254_2.jpg'), PosixPath('images/fulltest/7254_5.jpg'), PosixPath('images/fulltest/7254_1.jpg')]
# ----------------------------
# Parent :  44
# ----------------------------
# [PosixPath('images/fulltest/5979_4.jpg')]
# ----------------------------
# Parent :  368
# ----------------------------
# [PosixPath('images/fulltest/6239_3.jpg'), PosixPath('images/fulltest/6239_2.jpg'), PosixPath('images/fulltest/6239_4.jpg'), PosixPath('images/fulltest/6239_5.jpg'), PosixPath('images/fulltest/6239_1.jpg'), PosixPath('images/fulltest/6239_6.jpg')]
# ----------------------------
# Parent :  259
# ----------------------------
# [PosixPath('images/fulltest/1089_4.jpg'), PosixPath('images/fulltest/1089_3.jpg'), PosixPath('images/fulltest/1089_1.jpg'), PosixPath('images/fulltest/1089_5.jpg'), PosixPath('images/fulltest/1089_6.jpg'), PosixPath('images/fulltest/1089_2.jpg')]
# ----------------------------
# Parent :  47
# ----------------------------
# [PosixPath('images/fulltest/8222_1.jpg')]
# ----------------------------
# Parent :  216
# ----------------------------
# [PosixPath('images/fulltest/2630_4.jpg'), PosixPath('images/fulltest/2630_5.jpg'), PosixPath('images/fulltest/2630_6.jpg'), PosixPath('images/fulltest/2630_3.jpg'), PosixPath('images/fulltest/2630_2.jpg'), PosixPath('images/fulltest/2630_1.jpg')]
# ----------------------------
# Parent :  132
# ----------------------------
# [PosixPath('images/fulltest/2617_6.jpg'), PosixPath('images/fulltest/2617_2.jpg'), PosixPath('images/fulltest/2617_4.jpg'), PosixPath('images/fulltest/2617_1.jpg'), PosixPath('images/fulltest/2617_3.jpg'), PosixPath('images/fulltest/2617_5.jpg')]
# ----------------------------
# Parent :  288
# ----------------------------
# [PosixPath('images/fulltest/8385_4.jpg'), PosixPath('images/fulltest/8385_5.jpg'), PosixPath('images/fulltest/8385_1.jpg'), PosixPath('images/fulltest/8385_6.jpg')]
# ----------------------------
# Parent :  55
# ----------------------------
# [PosixPath('images/fulltest/8385_2.jpg')]
# ----------------------------
# Parent :  364
# ----------------------------
# [PosixPath('images/fulltest/6599_2.jpg'), PosixPath('images/fulltest/6599_6.jpg'), PosixPath('images/fulltest/6599_5.jpg'), PosixPath('images/fulltest/6599_4.jpg')]
# ----------------------------
# Parent :  385
# ----------------------------
# [PosixPath('images/fulltest/3555_2.jpg'), PosixPath('images/fulltest/3555_5.jpg'), PosixPath('images/fulltest/3555_4.jpg'), PosixPath('images/fulltest/3555_3.jpg'), PosixPath('images/fulltest/3555_1.jpg'), PosixPath('images/fulltest/3555_6.jpg')]
# ----------------------------
# Parent :  387
# ----------------------------
# [PosixPath('images/fulltest/5140_3.jpg'), PosixPath('images/fulltest/5140_6.jpg'), PosixPath('images/fulltest/5140_4.jpg'), PosixPath('images/fulltest/5140_5.jpg'), PosixPath('images/fulltest/5140_1.jpg'), PosixPath('images/fulltest/5140_2.jpg')]
# ----------------------------
# Parent :  328
# ----------------------------
# [PosixPath('images/fulltest/9938_1.jpg'), PosixPath('images/fulltest/9938_4.jpg'), PosixPath('images/fulltest/9938_2.jpg'), PosixPath('images/fulltest/9938_5.jpg'), PosixPath('images/fulltest/9938_3.jpg'), PosixPath('images/fulltest/9938_6.jpg')]
# ----------------------------
# Parent :  78
# ----------------------------
# [PosixPath('images/fulltest/1598_1.jpg')]
# ----------------------------
# Parent :  380
# ----------------------------
# [PosixPath('images/fulltest/2620_2.jpg'), PosixPath('images/fulltest/2620_6.jpg'), PosixPath('images/fulltest/2620_1.jpg'), PosixPath('images/fulltest/2620_3.jpg'), PosixPath('images/fulltest/2620_5.jpg'), PosixPath('images/fulltest/2620_4.jpg')]
# ----------------------------
# Parent :  311
# ----------------------------
# [PosixPath('images/fulltest/3377_2.jpg'), PosixPath('images/fulltest/3377_4.jpg'), PosixPath('images/fulltest/3377_5.jpg'), PosixPath('images/fulltest/3377_6.jpg'), PosixPath('images/fulltest/3377_1.jpg'), PosixPath('images/fulltest/3377_3.jpg')]
# ----------------------------
# Parent :  388
# ----------------------------
# [PosixPath('images/fulltest/10158_6.jpg'), PosixPath('images/fulltest/10158_2.jpg'), PosixPath('images/fulltest/10158_5.jpg'), PosixPath('images/fulltest/10158_4.jpg'), PosixPath('images/fulltest/10158_1.jpg'), PosixPath('images/fulltest/10158_3.jpg')]
# ----------------------------
# Parent :  389
# ----------------------------
# [PosixPath('images/fulltest/2625_6.jpg'), PosixPath('images/fulltest/2625_4.jpg'), PosixPath('images/fulltest/2625_5.jpg'), PosixPath('images/fulltest/2625_2.jpg'), PosixPath('images/fulltest/2625_1.jpg'), PosixPath('images/fulltest/2625_3.jpg')]
# ----------------------------
# Parent :  362
# ----------------------------
# [PosixPath('images/fulltest/2627_4.jpg'), PosixPath('images/fulltest/2627_1.jpg'), PosixPath('images/fulltest/2627_6.jpg'), PosixPath('images/fulltest/2627_5.jpg'), PosixPath('images/fulltest/2627_3.jpg'), PosixPath('images/fulltest/2627_2.jpg')]
# ----------------------------
# Parent :  381
# ----------------------------
# [PosixPath('images/fulltest/10507_3.jpg'), PosixPath('images/fulltest/10507_4.jpg'), PosixPath('images/fulltest/10507_1.jpg'), PosixPath('images/fulltest/10507_5.jpg'), PosixPath('images/fulltest/10507_2.jpg'), PosixPath('images/fulltest/10507_6.jpg')]
# ----------------------------
# Parent :  93
# ----------------------------
# [PosixPath('images/fulltest/4033_5.jpg')]
# ----------------------------
# Parent :  323
# ----------------------------
# [PosixPath('images/fulltest/2623_2.jpg'), PosixPath('images/fulltest/2623_5.jpg'), PosixPath('images/fulltest/2623_3.jpg'), PosixPath('images/fulltest/2623_4.jpg'), PosixPath('images/fulltest/2623_1.jpg'), PosixPath('images/fulltest/2623_6.jpg')]
# ----------------------------
# Parent :  355
# ----------------------------
# [PosixPath('images/fulltest/10953_3.jpg'), PosixPath('images/fulltest/10953_4.jpg'), PosixPath('images/fulltest/10953_5.jpg')]
# ----------------------------
# Parent :  386
# ----------------------------
# [PosixPath('images/fulltest/3521_2.jpg'), PosixPath('images/fulltest/3521_4.jpg'), PosixPath('images/fulltest/3521_6.jpg'), PosixPath('images/fulltest/3521_5.jpg'), PosixPath('images/fulltest/3521_3.jpg'), PosixPath('images/fulltest/3521_1.jpg')]
# ----------------------------
# Parent :  285
# ----------------------------
# [PosixPath('images/fulltest/2619_5.jpg'), PosixPath('images/fulltest/2619_3.jpg'), PosixPath('images/fulltest/2619_1.jpg'), PosixPath('images/fulltest/2619_6.jpg'), PosixPath('images/fulltest/2619_4.jpg'), PosixPath('images/fulltest/2619_2.jpg')]
# ----------------------------
# Parent :  384
# ----------------------------
# [PosixPath('images/fulltest/2624_4.jpg'), PosixPath('images/fulltest/2624_2.jpg'), PosixPath('images/fulltest/2624_6.jpg'), PosixPath('images/fulltest/2624_3.jpg'), PosixPath('images/fulltest/2624_5.jpg'), PosixPath('images/fulltest/2624_1.jpg')]
# ----------------------------
# Parent :  395
# ----------------------------
# [PosixPath('images/fulltest/6626_2.jpg'), PosixPath('images/fulltest/6626_1.jpg'), PosixPath('images/fulltest/6626_5.jpg'), PosixPath('images/fulltest/6626_6.jpg'), PosixPath('images/fulltest/6626_3.jpg'), PosixPath('images/fulltest/6626_4.jpg')]
# ----------------------------
# Parent :  349
# ----------------------------
# [PosixPath('images/fulltest/7284_1.jpg'), PosixPath('images/fulltest/7284_2.jpg'), PosixPath('images/fulltest/7284_4.jpg'), PosixPath('images/fulltest/7284_6.jpg'), PosixPath('images/fulltest/7284_3.jpg'), PosixPath('images/fulltest/7284_5.jpg')]
# ----------------------------
# Parent :  366
# ----------------------------
# [PosixPath('images/fulltest/10453_1.jpg'), PosixPath('images/fulltest/10453_5.jpg'), PosixPath('images/fulltest/10453_2.jpg'), PosixPath('images/fulltest/10453_4.jpg'), PosixPath('images/fulltest/10453_6.jpg'), PosixPath('images/fulltest/10453_3.jpg')]
# ----------------------------
# Parent :  371
# ----------------------------
# [PosixPath('images/fulltest/7524_2.jpg'), PosixPath('images/fulltest/7524_6.jpg'), PosixPath('images/fulltest/7524_4.jpg'), PosixPath('images/fulltest/7524_5.jpg'), PosixPath('images/fulltest/7524_1.jpg'), PosixPath('images/fulltest/7524_3.jpg')]
# ----------------------------
# Parent :  306
# ----------------------------
# [PosixPath('images/fulltest/11350_3.jpg'), PosixPath('images/fulltest/11350_5.jpg'), PosixPath('images/fulltest/11350_1.jpg'), PosixPath('images/fulltest/11350_2.jpg'), PosixPath('images/fulltest/11350_4.jpg'), PosixPath('images/fulltest/11350_6.jpg')]
# ----------------------------
# Parent :  145
# ----------------------------
# [PosixPath('images/fulltest/4033_3.jpg')]
# ----------------------------
# Parent :  147
# ----------------------------
# [PosixPath('images/fulltest/6599_3.jpg')]
# ----------------------------
# Parent :  284
# ----------------------------
# [PosixPath('images/fulltest/5141_6.jpg'), PosixPath('images/fulltest/5141_3.jpg'), PosixPath('images/fulltest/5141_2.jpg'), PosixPath('images/fulltest/5141_1.jpg'), PosixPath('images/fulltest/5141_5.jpg'), PosixPath('images/fulltest/5141_4.jpg')]
# ----------------------------
# Parent :  154
# ----------------------------
# [PosixPath('images/fulltest/6599_1.jpg')]
# ----------------------------
# Parent :  399
# ----------------------------
# [PosixPath('images/fulltest/1598_4.jpg'), PosixPath('images/fulltest/1598_6.jpg'), PosixPath('images/fulltest/1598_5.jpg'), PosixPath('images/fulltest/1598_3.jpg'), PosixPath('images/fulltest/1598_2.jpg')]
# ----------------------------
# Parent :  356
# ----------------------------
# [PosixPath('images/fulltest/5979_1.jpg'), PosixPath('images/fulltest/5979_2.jpg')]
# ----------------------------
# Parent :  175
# ----------------------------
# [PosixPath('images/fulltest/5979_6.jpg')]
# ----------------------------
# Parent :  191
# ----------------------------
# [PosixPath('images/fulltest/6625_3.jpg')]
# ----------------------------
# Parent :  391
# ----------------------------
# [PosixPath('images/fulltest/7597_5.jpg'), PosixPath('images/fulltest/7597_2.jpg'), PosixPath('images/fulltest/7597_3.jpg'), PosixPath('images/fulltest/7597_1.jpg'), PosixPath('images/fulltest/7597_6.jpg'), PosixPath('images/fulltest/7597_4.jpg')]
# ----------------------------
# Parent :  236
# ----------------------------
# [PosixPath('images/fulltest/8385_3.jpg')]
# ----------------------------
# Parent :  394
# ----------------------------
# [PosixPath('images/fulltest/10536_4.jpg'), PosixPath('images/fulltest/10536_2.jpg'), PosixPath('images/fulltest/10536_3.jpg'), PosixPath('images/fulltest/10536_1.jpg'), PosixPath('images/fulltest/10536_6.jpg'), PosixPath('images/fulltest/10536_5.jpg')]
# ----------------------------
# Parent :  377
# ----------------------------
# [PosixPath('images/fulltest/10953_2.jpg'), PosixPath('images/fulltest/10953_6.jpg'), PosixPath('images/fulltest/10953_1.jpg')]
# ----------------------------
# Parent :  334
# ----------------------------
# [PosixPath('images/fulltest/6623_4.jpg')]
# ----------------------------
# Parent :  360
# ----------------------------
# [PosixPath('images/fulltest/5979_5.jpg')]
# ----------------------------
# Parent :  396
# ----------------------------
# [PosixPath('images/fulltest/5979_3.jpg')]
# ----------------------------
# Parent :  400
# ----------------------------
# [PosixPath('images/fulltest/4033_1.jpg')]
# 77
# 16
